# %%
import mat73
import numpy as np

# %%
filename = "NDNFindivsomata_GLM.mat"
data_dict = mat73.loadmat(filename)

# %%
data_dict['animal'].keys()
# Out:
# dict_keys(['ShiftLrate', 'ShiftR', 'ShiftRunning', 'ShiftV'])

# %%
data_dict['animal']['ShiftV'][1].shape
# Out:
# (50, 159)

# %%
data_dict['animal']['ShiftR'][1].shape
# Out:
# (50, 428, 15)

# %%
data = data_dict['animal']['ShiftRunning'][0].T
print(data.shape)
plt.imshow(data)
plt.colorbar()
plt.show()
# Out:
# (213, 50)
